# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from config import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 604

# %%
print(cities)
# Out:
# ['asau', 'tyrma', 'sechura', 'carnarvon', 'amderma', 'mataura', 'cidreira', 'butaritari', 'vaini', 'tahe', 'hilo', 'hermanus', 'atuona', 'belushya guba', 'molina', 'rikitea', 'barentsburg', 'victoria', 'nelson bay', 'bethel', 'ahuimanu', 'taolanaro', 'avarua', 'illoqqortoormiut', 'kaitangata', 'nome', 'airai', 'arlit', 'altay', 'saint-augustin', 'cherskiy', 'sinjar', 'arraial do cabo', 'esperance', 'riyadh', 'elliot lake', 'bismarck', 'mahebourg', 'nizhneyansk', 'kapaa', 'coihaique', 'palabuhanratu', 'korla', 'qaqortoq', 'sorong', 'kokoda', 'jamestown', 'mount gambier', 'kodiak', 'anqing', 'punta arenas', 'new norfolk', 'college', 'togur', 'shingu', 'bredasdorp', 'ushuaia', 'chuy', 'maraba', 'san rafael', 'saint-philippe', 'benito juarez', 'bluff', 'attawapiskat', 'port alfred', 'utrecht', 'pisco', 'saldanha', 'parras', 'san felipe', 'te anau', 'fort frances', 'klaksvik', 'phaltan', 'vaitape', 'enumclaw', 'albany', 'tiksi', 'zaykovo', 'bambous virieux', 'khatanga', 'acapulco', 'umzimvubu', 'sentyabrskiy', 'itarema', 'waipawa', 'jahrom', 'san cristobal', 'fortuna', 'kenai', 'lingyuan', 'vardo', 'saint george', 'half moon bay', 'mar del plata', 'honiara', 'georgetown', 'fasa', 'saint anthony', 'mayo', 'kelvington', 'caravelas', 'busselton', 'kailua', 'strelka', 'saleaula', 'casian', 'cabedelo', 'tuktoyaktuk', 'longyearbyen', 'hobart', 'ilhabela', 'barrow', 'port elizabeth', 'oksfjord', 'tessalit', 'mys shmidta', 'bozeman', 'ponta do sol', 'lovozero', 'severo-kurilsk', 'baker city', 'svetlogorsk', 'lodwar', 'jardim', 'la libertad', 'camopi', 'kahului', 'port hawkesbury', 'bengkulu', 'yellowknife', 'narsaq', 'north bend', 'galgani', 'susanville', 'chirala', 'salalah', 'port blair', 'olhao', 'luwuk', 'luganville', 'port hardy', 'rungata', 'goderich', 'monrovia', 'kudat', 'torbay', 'touros', 'arkhangelsk', 'ituango', 'grindavik', 'buraydah', 'kharan', 'kuito', 'ayolas', 'katsuura', 'puerto ayora', 'yumen', 'cape town', 'verkhnevilyuysk', 'eyl', 'qaanaaq', 'tautira', 'ji-parana', 'kutum', 'kolimvari', 'duz', 'mlonggo', 'lima', 'owensboro', 'necochea', 'abu dhabi', 'le port', 'geraldton', 'krasnokamensk', 'mahadday weyne', 'kalmunai', 'ilulissat', 'dikson', 'castro', 'la romana', 'sao joao da barra', 'sinkat', 'east london', 'jinxiang', 'coelho neto', 'reconquista', 'fare', 'helong', 'san carlos de bariloche', 'damaturu', 'husavik', 'ribeira grande', 'tarko-sale', 'catio', 'provideniya', 'gazanjyk', 'haibowan', 'bijar', 'zhob', 'masallatah', 'nam phong', 'severodvinsk', 'manaus', 'yarada', 'liepaja', 'clyde river', 'hithadhoo', 'boguchany', 'merauke', 'saskylakh', 'sorvag', 'mendahara', 'oltu', 'muros', 'sabzevar', 'san andres', 'sebastian', 'chokurdakh', 'gramoteino', 'bom jesus', 'naze', 'sao filipe', 'chumikan', 'simi', 'odweyne', 'batagay-alyta', 'moron', 'procida', 'khash', 'kaupanger', 'benguela', 'lebu', 'vaitupu', 'aljezur', 'muzhi', 'ballina', 'trincomalee', 'pevek', 'montrose', 'artyk', 'little current', 'chaumont', 'general roca', 'andros town', 'longlac', 'guane', 'belyy yar', 'corowa', 'alofi', 'tashtagol', 'beringovskiy', 'bargal', 'champerico', 'sokolac', 'luderitz', 'tadine', 'dolbeau', 'kautokeino', 'ketchikan', 'sainte-martine', 'upernavik', 'kruisfontein', 'plastun', 'vila', 'tazovskiy', 'pontarlier', 'vyshneve', 'nanortalik', 'samusu', 'faanui', 'kavaratti', 'hasaki', 'batamshinskiy', 'praxedis guerrero', 'urumqi', 'winslow', 'puqi', 'lompoc', 'nazca', 'hobyo', 'kavieng', 'havre-saint-pierre', 'iqaluit', 'terrace', 'maceio', 'mount isa', 'longkou', 'dhidhdhoo', 'guerrero negro', 'xining', 'seynod', 'santarem', 'petropavlovsk-kamchatskiy', 'luau', 'yeppoon', 'tsihombe', 'oistins', 'tasiilaq', 'thompson', 'juegang', 'breves', 'karratha', 'jiuquan', 'pabrade', 'chik', 'novoagansk', 'yulara', 'saint-louis', 'walvis bay', 'miri', 'sao felix do xingu', 'inhambane', 'lagoa', 'san pedro', 'sri aman', 'sakaiminato', 'port lincoln', 'vagur', 'bolshoye sorokino', 'isangel', 'whakatane', 'shilka', 'beloha', 'kotido', 'ituni',  ...

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
#Practice json request see how the data is formatted

url = "https://api.openweathermap.org/data/2.5/weather?q=London&appid={weather_api_key}"
city =" London"
response = requests.get(url)


weather_response = requests.get(url)
weather_json = weather_response.json()

# Get the temperature from the response
print(f"The weather API responded with: {weather_json}.")
# Out:
# The weather API responded with: {'cod': 401, 'message': 'Invalid API key. Please see https://openweathermap.org/faq#error401 for more info.'}.

# %%
import requests

# Set the API base URL
base_url = "http://api.openweathermap.org/data/2.5/weather?"
weather_api_key = "weather_api_key"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    endpoint = f"{base_url}q={city}&appid={weather_api_key}"
    
    # Log the endpoint, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Send an API request for each city
        response = requests.get(endpoint)

        # Parse the JSON and retrieve data
        city_weather = response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather(["main"]["temp_max"]- 273.15) * 9/5 + 32
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        
        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# City not found. Skipping...
# Processing Record 2 of Set 1 | mahajanga
# City not found. Skipping...
# Processing Record 3 of Set 1 | sao joao da barra
# City not found. Skipping...
# Processing Record 4 of Set 1 | ridgecrest
# City not found. Skipping...
# Processing Record 5 of Set 1 | ushuaia
# City not found. Skipping...
# Processing Record 6 of Set 1 | kaitangata
# City not found. Skipping...
# Processing Record 7 of Set 1 | ribeira grande
# City not found. Skipping...
# Processing Record 8 of Set 1 | rio gallegos
# City not found. Skipping...
# Processing Record 9 of Set 1 | arraial do cabo
# City not found. Skipping...
# Processing Record 10 of Set 1 | jalu
# City not found. Skipping...
# Processing Record 11 of Set 1 | tiksi
# City not found. Skipping...
# Processing Record 12 of Set 1 | torbay
# City not found. Skipping...
# Processing Record 13 of Set 1 | tasiilaq
# City not found. Skipping...
# Processing Record 14 of Set 1 | hobart
# City not found. Skipping...
# Processing Record 15 of Set 1 | teguldet
# City not found. Skipping...
# Processing Record 16 of Set 1 | cherskiy
# City not found. Skipping...
# Processing Record 17 of Set 1 | bethel
# City not found. Skipping...
# Processing Record 18 of Set 1 | aykhal
# City not found. Skipping...
# Processing Record 19 of Set 1 | pedernales
# City not found. Skipping...
# Processing Record 20 of Set 1 | bredasdorp
# City not found. Skipping...
# Processing Record 21 of Set 1 | betafo
# City not found. Skipping...
# Processing Record 22 of Set 1 | cape town
# City not found. Skipping...
# Processing Record 23 of Set 1 | george
# City not found. Skipping...
# Processing Record 24 of Set 1 | gollere
# City not found. Skipping...
# Processing Record 25 of Set 1 | lubango
# City not found. Skipping...
# Processing Record 26 of Set 1 | chokurdakh
# City not found. Skipping...
# Processing Record 27 of Set 1 | rikitea
# City not found. Skipping...
# Processing Record 28 of Set 1 | waipawa
# City not found. Skipping...
# Processing Record 29 of Set 1 | tahta
# City not found. Skipping...
# Processing Record 30 of Set 1 | dakar
# City not found. Skipping...
# Processing Record 31 of Set 1 | qaanaaq
# City not found. Skipping...
# Processing Record 32 of Set 1 | isangel
# City not found. Skipping...
# Processing Record 33 of Set 1 | ponta delgada
# City not found. Skipping...
# Processing Record 34 of Set 1 | jamestown
# City not found. Skipping...
# Processing Record 35 of Set 1 | mulino
# City not found. Skipping...
# Processing Record 36 of Set 1 | saskylakh
# City not found. Skipping...
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | santa isabel
# City not found. Skipping...
# Processing Record 39 of Set 1 | new norfolk
# City not found. Skipping...
# Processing Record 40 of Set 1 | taree
# City not found. Skipping...
# Processing Record 41 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 1 | busselton
# City not found. Skipping...
# Processing Record 43 of Set 1 | edd
# City not found. Skipping...
# Processing Record 44 of Set 1 | chuy
# City not found. Skipping...
# Processing Record 45 of Set 1 | bluefield
# City not found. Skipping...
# Processing Record 46 of Set 1 | takoradi
# City not found. Skipping...
# Processing Record 47 of Set 1 | albany
# City not found. Skipping...
# Processing Record 48 of Set 1 | vallenar
# City not found. Skipping...
# Processing Record 49 of Set 1 | beringovskiy
# City not found. Skipping...
# Processing Record 50 of Set 1 | faya
# City not found. Skipping...
# Processing Record 0 of Set 2 | punta arenas
# City not found. Skipping...
# Processing Record 1 of Set 2 | thompson
# City not found. Skipping...
# Processing Record 2 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 2 | nikolskoye
# City not found. Skipping...
# Processing Record 4 of Set 2 | puerto ayora
# City not found. Skipping...
# Processing Record 5 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 2 | aktash
# City not found. Skipping...
# Processing Record 10 of Set 2 | laurens
# City not found. Skipping...
# Processing Record 11 of Set 2 | turkeve
# City not found. Skipping...
# Processing Record 12 of Set 2 | yerbogachen
# City not found. Skipping...
# Processing Record 13 of Set 2 | kaputa
# City not found. Skipping...
# Processing Record 14 of Set 2 | padang
# City not found. Skipping...
# Processing Record 15 of Set 2 | ko samui
# City not found. Skipping...
# Processing Record 16 of Set 2 | mogadishu
# City not found. Skipping...
# Processing Record 17 of Set 2 | port alfred
# City not found. Skipping...
# Processing Record 18 of Set 2 | mahebourg
# City not found. Skipping...
# Processing Record 19 of Set 2 | ilulissat
# City not found. Skipping...
# Processing Record 20 of Set 2 | griffith
# City not found. Skipping...
# Processing Record 21 of Set 2 | puerto colombia
# City not found. Skipping...
# Processing Record 22 of Set 2 | chalus
# City not found. Skipping...
# Processing Record 23 of Set 2 | namibe
# City not found. Skipping...
# Processing Record 24 of Set 2 | tuktoyaktuk
# City not found. Skipping...
# Processing Record 25 of Set 2 | clyde river
# City not found. Skipping...
# Processing Record 26 of Set 2 | souillac
# City not found. Skipping...
# Processing Record 27 of Set 2 | ancud
# City not found. Skipping...
# Processing Record 28 of Set 2 | esperance
# City not found. Skipping...
# Processing Record 29 of Set 2 | beroroha
# City not found. Skipping...
# Processing Record 30 of Set 2 | saint george
# City not found. Skipping...
# Processing Record 31 of Set 2 | vila velha
# City not found. Skipping...
# Processing Record 32 of Set 2 | hithadhoo
# City not found. Skipping...
# Processing Record 33 of Set 2 | megion
# City not found. Skipping...
# Processing Record 34 of Set 2 | sechura
# City not found. Skipping...
# Processing Record 35 of Set 2 | east london
# City not found. Skipping...
# Processing Record 36 of Set 2 | xining
# City not found. Skipping...
# Processing Record 37 of Set 2 | buin
# City not found. Skipping...
# Processing Record 38 of Set 2 | khatanga
# City not found. Skipping...
# Processing Record 39 of Set 2 | elizabeth city
# City not found. Skipping...
# Processing Record 40 of Set 2 | ostrovnoy
# City not found. Skipping...
# Processing Record 41 of Set 2 | bengkulu
# City not found. Skipping...
# Processing Record 42 of Set 2 | tarudant
# City not found. Skipping...
# Processing Record 43 of Set 2 | chapais
# City not found. Skipping...
# Processing Record 44 of Set 2 | nanortalik
# City not found. Skipping...
# Processing Record 45 of Set 2 | carnarvon
# City not found. Skipping...
# Processing Record 46 of Set 2 | rozkishne
# City not found. Skipping...
# Processing Record 47 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 2 | victoria
# City not found. Skipping...
# Processing Record 49 of Set 2 | bluff
# City not found. Skipping...
# Processing Record 0 of Set 3 | port lincoln
# City not found. Skipping...
# Processing Record 1 of Set 3 | college
# City not found. Skipping...
# Processing Record 2 of Set 3 | giyon
# City not found. Skipping...
# Processing Record 3 of Set 3 | malatya
# City not found. Skipping...
# Processing Record 4 of Set 3 | broome
# City not found. Skipping...
# Processing Record 5 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 3 | kloulklubed
# City not found. Skipping...
# Processing Record 7 of Set 3 | batagay-alyta
# City not found. Skipping...
# Processing Record 8 of Set 3 | mudgal
# City not found. Skipping...
# Processing Record 9 of Set 3 | sibenik
# City not found. Skipping...
# Processing Record 10 of Set 3 | lethem
# City not found. Skipping...
# Processing Record 11 of Set 3 | hilo
# City not found. Skipping...
# Processing Record 12 of Set 3 | blythe
# City not found. Skipping...
# Processing Record 13 of Set 3 | gat
# City not found. Skipping...
# Processing Record 14 of Set 3 | komagane
# City not found. Skipping...
# Processing Record 15 of Set 3 | quimperle
# City not found. Skipping...
# Processing Record 16 of Set 3 | upernavik
# City not found. Skipping...
# Processing Record 17 of Set 3 | faanui
# City not found. Skipping...
# Processing Record 18 of Set 3 | ixtapa
# City not found. Skipping...
# Processing Record 19 of Set 3 | lebu
# City not found. Skipping...
# Processing Record 20 of Set 3 | kavieng
# City not found. Skipping...
# Processing Record 21 of Set 3 | alexandria
# City not found. Skipping...
# Processing Record 22 of Set 3 | camopi
# City not found. Skipping...
# Processing Record 23 of Set 3 | mar del plata
# City not found. Skipping...
# Processing Record 24 of Set 3 | hermanus
# City not found. Skipping...
# Processing Record 25 of Set 3 | atuona
# City not found. Skipping...
# Processing Record 26 of Set 3 | kawalu
# City not found. Skipping...
# Processing Record 27 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 28 of Set 3 | amahai
# City not found. Skipping...
# Processing Record 29 of Set 3 | yulara
# City not found. Skipping...
# Processing Record 30 of Set 3 | ust-nera
# City not found. Skipping...
# Processing Record 31 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 3 | nemuro
# City not found. Skipping...
# Processing Record 33 of Set 3 | olafsvik
# City not found. Skipping...
# Processing Record 34 of Set 3 | luanda
# City not found. Skipping...
# Processing Record 35 of Set 3 | ngunguru
# City not found. Skipping...
# Processing Record 36 of Set 3 | saint-pierre
# City not found. Skipping...
# Processing Record 37 of Set 3 | belyy yar
# City not found. Skipping...
# Processing Record 38 of Set 3 | kapaa
# City not found. Skipping...
# Processing Record 39 of Set 3 | meiringen
# City not found. Skipping...
# Processing Record 40 of Set 3 | cururupu
# City not found. Skipping...
# Processing Record 41 of Set 3 | geraldton
# City not found. Skipping...
# Processing Record 42 of Set 3 | husavik
# City not found. Skipping...
# Processing Record 43 of Set 3 | skjervoy
# City not found. Skipping...
# Processing Record 44 of Set 3 | algiers
# City not found. Skipping...
# Processing Record 45 of Set 3 | inirida
# City not found. Skipping...
# Processing Record 46 of Set 3 | aripuana
# City not found. Skipping...
# Processing Record 47 of Set 3 | ambovombe
# City not found. Skipping...
# Processing Record 48 of Set 3 | longyearbyen
# City not found. Skipping...
# Processing Record 49 of Set 3 | provideniya
# City not found. Skipping...
# Processing Record 0 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 4 | los llanos de aridane
# City not found. Skipping...
# Processing Record 2 of Set 4 | susehri
# City not found. Skipping...
# Processing Record 3 of Set 4 | angoche
# City not found. Skipping...
# Processing Record 4 of Set 4 | skibotn
# City not found. Skipping...
# Processing Record 5 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 4 | rawlins
# City not found. Skipping...
# Processing Record 7 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 4 | vila franca do campo
# City not found. Skipping...
# Processing Record 9 of Set 4 | warri
# City not found. Skipping...
# Processing Record 10 of Set 4 | pahrump
# City not found. Skipping...
# Processing Record 11 of Set 4 | yellowknife
# City not found. Skipping...
# Processing Record 12 of Set 4 | kyzyl-mazhalyk
# City not found. Skipping...
# Processing Record 13 of Set 4 | nampa
# City not found. Skipping...
# Processing Record 14 of Set 4 | namatanai
# City not found. Skipping...
# Processing Record 15 of Set 4 | grand gaube
# City not found. Skipping...
# Processing Record 16 of Set 4 | pemangkat
# City not found. Skipping...
# Processing Record 17 of Set 4 | dhidhdhoo
# City not found. Skipping...
# Processing Record 18 of Set 4 | mayor pablo lagerenza
# City not found. Skipping...
# Processing Record 19 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 4 | sidney
# City not found. Skipping...
# Processing Record 21 of Set 4 | sisimiut
# City not found. Skipping...
# Processing Record 22 of Set 4 | egvekinot
# City not found. Skipping...
# Processing Record 23 of Set 4 | tessalit
# City not found. Skipping...
# Processing Record 24 of Set 4 | severo-kurilsk
# City not found. Skipping...
# Processing Record 25 of Set 4 | kedougou
# City not found. Skipping...
# Processing Record 26 of Set 4 | nago
# City not found. Skipping...
# Processing Record 27 of Set 4 | talcahuano
# City not found. Skipping...
# Processing Record 28 of Set 4 | camacupa
# City not found. Skipping...
# Processing Record 29 of Set 4 | dikson
# City not found. Skipping...
# Processing Record 30 of Set 4 | soyo
# City not found. Skipping...
# Processing Record 31 of Set 4 | kapoeta
# City not found. Skipping...
# Processing Record 32 of Set 4 | coquimbo
# City not found. Skipping...
# Processing Record 33 of Set 4 | nanakuli
# City not found. Skipping...
# Processing Record 34 of Set 4 | erhlin
# City not found. Skipping...
# Processing Record 35 of Set 4 | ler
# City not found. Skipping...
# Processing Record 36 of Set 4 | salamanca
# City not found. Skipping...
# Processing Record 37 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 4 | verkhnevilyuysk
# City not found. Skipping...
# Processing Record 40 of Set 4 | casino
# City not found. Skipping...
# Processing Record 41 of Set 4 | avarua
# City not found. Skipping...
# Processing Record 42 of Set 4 | vaini
# City not found. Skipping...
# Processing Record 43 of Set 4 | kuloy
# City not found. Skipping...
# Processing Record 44 of Set 4 | dayong
# City not found. Skipping...
# Processing Record 45 of Set 4 | tevaitoa
# City not found. Skipping...
# Processing Record 46 of Set 4 | tula
# City not found. Skipping...
# Processing Record 47 of Set 4 | hamilton
# City not found. Skipping...
# Processing Record 48 of Set 4 | ramgarh
# City not found. Skipping...
# Processing Record 49 of Set 4 | mirnyy
# City not found. Skipping...
# Processing Record 0 of Set 5 | staraya kulatka
# City not found. Skipping...
# Processing Record 1 of Set 5 | buala
# City not found. Skipping...
# Processing Record 2 of Set 5 | krasnoselkup
# City not found. Skipping...
# Processing Record 3 of Set 5 | northam
# City not found. Skipping...
# Processing Record 4 of Set 5 | rawah
# City not found. Skipping...
# Processing Record 5 of Set 5 | rawson
# City not found. Skipping...
# Processing Record 6 of Set 5 | jahrom
# City not found. Skipping...
# Processing Record 7 of Set 5 | murwillumbah
# City not found. Skipping...
# Processing Record 8 of Set 5 | san quintin
# City not found. Skipping...
# Processing Record 9 of Set 5 | waingapu
# City not found. Skipping...
# Processing Record 10 of Set 5 | sabzevar
# City not found. Skipping...
# Processing Record 11 of Set 5 | villazon
# City not found. Skipping...
# Processing Record 12 of Set 5 | marquette
# City not found. Skipping...
# Processing Record 13 of Set 5 | vredendal
# City not found. Skipping...
# Processing Record 14 of Set 5 | zhenhai
# City not found. Skipping...
# Processing Record 15 of Set 5 | nadym
# City not found. Skipping...
# Processing Record 16 of Set 5 | burlington
# City not found. Skipping...
# Processing Record 17 of Set 5 | lusambo
# City not found. Skipping...
# Processing Record 18 of Set 5 | batticaloa
# City not found. Skipping...
# Processing Record 19 of Set 5 | seoul
# City not found. Skipping...
# Processing Record 20 of Set 5 | rayon
# City not found. Skipping...
# Processing Record 21 of Set 5 | yashkino
# City not found. Skipping...
# Processing Record 22 of Set 5 | mont-dore
# City not found. Skipping...
# Processing Record 23 of Set 5 | reefton
# City not found. Skipping...
# Processing Record 24 of Set 5 | castro
# City not found. Skipping...
# Processing Record 25 of Set 5 | libreville
# City not found. Skipping...
# Processing Record 26 of Set 5 | royan
# City not found. Skipping...
# Processing Record 27 of Set 5 | urumqi
# City not found. Skipping...
# Processing Record 28 of Set 5 | airai
# City not found. Skipping...
# Processing Record 29 of Set 5 | xiamen
# City not found. Skipping...
# Processing Record 30 of Set 5 | mount gambier
# City not found. Skipping...
# Processing Record 31 of Set 5 | port elizabeth
# City not found. Skipping...
# Processing Record 32 of Set 5 | neiafu
# City not found. Skipping...
# Processing Record 33 of Set 5 | kapuskasing
# City not found. Skipping...
# Processing Record 34 of Set 5 | hasaki
# City not found. Skipping...
# Processing Record 35 of Set 5 | henties bay
# City not found. Skipping...
# Processing Record 36 of Set 5 | asau
# City not found. Skipping...
# Processing Record 37 of Set 5 | samarai
# City not found. Skipping...
# Processing Record 38 of Set 5 | rakamaz
# City not found. Skipping...
# Processing Record 39 of Set 5 | victor harbor
# City not found. Skipping...
# Processing Record 40 of Set 5 | ekhabi
# City not found. Skipping...
# Processing Record 41 of Set 5 | cartagena
# City not found. Skipping...
# Processing Record 42 of Set 5 | butaritari
# City not found. Skipping...
# Processing Record 43 of Set 5 | luderitz
# City not found. Skipping...
# Processing Record 44 of Set 5 | norman wells
# City not found. Skipping...
# Processing Record 45 of Set 5 | baker city
# City not found. Skipping...
# Processing Record 46 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 47 of Set 5 | samarkand
# City not found. Skipping...
# Processing Record 48 of Set 5 | takaka
# City not found. Skipping...
# Processing Record 49 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 0 of Set 6 | vestmannaeyjar
# City not found. Skipping...
# Processing Record 1 of Set 6 | thakurganj
# City not found. Skipping...
# Processing Record 2 of Set 6 | northfield
# City not found. Skipping...
# Processing Record 3 of Set 6 | richmond
# City not found. Skipping...
# Processing Record 4 of Set 6 | linxia
# City not found. Skipping...
# Processing Record 5 of Set 6 | vao
# City not found. Skipping...
# Processing Record 6 of Set 6 | inuvik
# City not found. Skipping...
# Processing Record 7 of Set 6 | malaya vishera
# City not found. Skipping...
# Processing Record 8 of Set 6 | fethiye
# City not found. Skipping...
# Processing Record 9 of Set 6 | lorengau
# City not found. Skipping...
# Processing Record 10 of Set 6 | karratha
# City not found. Skipping...
# Processing Record 11 of Set 6 | noumea
# City not found. Skipping...
# Processing Record 12 of Set 6 | san juan
# City not found. Skipping...
# Processing Record 13 of Set 6 | dingle
# City not found. Skipping...
# Processing Record 14 of Set 6 | krasnogvardeyskiy
# City not found. Skipping...
# Processing Record 15 of Set 6 | tazmalt
# City not found. Skipping...
# Processing Record 16 of Set 6 | hukuntsi
# City not found. Skipping...
# Processing Record 17 of Set 6 | spirit river
# City not found. Skipping...
# Processing Record 18 of Set 6 | lompoc
# City not found. Skipping...
# Processing Record 19 of Set 6 | sargatskoye
# City not found. Skipping...
# Processing Record 20 of Set 6 | santa cruz
# City not found. Skipping...
# Processing Record 21 of Set 6 | thunder bay
# City not found. Skipping...
# Processing Record 22 of Set 6 | tuatapere
# City not found. Skipping...
# Processing Record 23 of Set 6 | adre
# City not found. Skipping...
# Processing Record 24 of Set 6 | mabaruma
# City not found. Skipping...
# Processing Record 25 of Set 6 | kodiak
# City not found. Skipping...
# Processing Record 26 of Set 6 | dumra
# City not found. Skipping...
# Processing Record 27 of Set 6 | bandarbeyla
# City not found. Skipping...
# Processing Record 28 of Set 6 | virginia beach
# City not found. Skipping...
# Processing Record 29 of Set 6 | polson
# City not found. Skipping...
# Processing Record 30 of Set 6 | lakatoro
# City not found. Skipping...
# Processing Record 31 of Set 6 | vershino-shakhtaminskiy
# City not found. Skipping...
# Processing Record 32 of Set 6 | nenjiang
# City not found. Skipping...
# Processing Record 33 of Set 6 | doha
# City not found. Skipping...
# Processing Record 34 of Set 6 | bathsheba
# City not found. Skipping...
# Processing Record 35 of Set 6 | varberg
# City not found. Skipping...
# Processing Record 36 of Set 6 | kruisfontein
# City not found. Skipping...
# Processing Record 37 of Set 6 | te anau
# City not found. Skipping...
# Processing Record 38 of Set 6 | tecolutla
# City not found. Skipping...
# Processing Record 39 of Set 6 | eureka
# City not found. Skipping...
# Processing Record 40 of Set 6 | sosva
# City not found. Skipping...
# Processing Record 41 of Set 6 | mount isa
# City not found. Skipping...
# Processing Record 42 of Set 6 | cidreira
# City not found. Skipping...
# Processing Record 43 of Set 6 | mackenzie
# City not found. Skipping...
# Processing Record 44 of Set 6 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 45 of Set 6 | canico
# City not found. Skipping...
# Processing Record 46 of Set 6 | richards bay
# City not found. Skipping...
# Processing Record 47 of Set 6 | lubao
# City not found. Skipping...
# Processing Record 48 of Set 6 | puri
# City not found. Skipping...
# Processing Record 49 of Set 6 | muli
# City not found. Skipping...
# Processing Record 0 of Set 7 | biloela
# City not found. Skipping...
# Processing Record 1 of Set 7 | palana
# City not found. Skipping...
# Processing Record 2 of Set 7 | guayaramerin
# City not found. Skipping...
# Processing Record 3 of Set 7 | llangefni
# City not found. Skipping...
# Processing Record 4 of Set 7 | gijon
# City not found. Skipping...
# Processing Record 5 of Set 7 | cuyo
# City not found. Skipping...
# Processing Record 6 of Set 7 | illela
# City not found. Skipping...
# Processing Record 7 of Set 7 | biak
# City not found. Skipping...
# Processing Record 8 of Set 7 | monastyrshchina
# City not found. Skipping...
# Processing Record 9 of Set 7 | flinders
# City not found. Skipping...
# Processing Record 10 of Set 7 | pokaran
# City not found. Skipping...
# Processing Record 11 of Set 7 | bubaque
# City not found. Skipping...
# Processing Record 12 of Set 7 | belaya gora
# City not found. Skipping...
# Processing Record 13 of Set 7 | seymchan
# City not found. Skipping...
# Processing Record 14 of Set 7 | buchanan
# City not found. Skipping...
# Processing Record 15 of Set 7 | cayenne
# City not found. Skipping...
# Processing Record 16 of Set 7 | sindand
# City not found. Skipping...
# Processing Record 17 of Set 7 | saint-philippe
# City not found. Skipping...
# Processing Record 18 of Set 7 | yatsushiro
# City not found. Skipping...
# Processing Record 19 of Set 7 | thap than
# City not found. Skipping...
# Processing Record 20 of Set 7 | tilichiki
# City not found. Skipping...
# Processing Record 21 of Set 7 | bintulu
# City not found. Skipping...
# Processing Record 22 of Set 7 | la ronge
# City not found. Skipping...
# Processing Record 23 of Set 7 | fortuna
# City not found. Skipping...
# Processing Record 24 of Set 7 | kampene
# City not found. Skipping...
# Processing Record 25 of Set 7 | portland
# City not found. Skipping...
# Processing Record 26 of Set 7 | kilindoni
# City not found. Skipping...
# Processing Record 27 of Set 7 | pisco
# City not found. Skipping...
# Processing Record 28 of Set 7 | havre-saint-pierre
# City not found. Skipping...
# Processing Record 29 of Set 7 | sarkand
# City not found. Skipping...
# Processing Record 30 of Set 7 | am timan
# City not found. Skipping...
# Processing Record 31 of Set 7 | nyimba
# City not found. Skipping...
# Processing Record 32 of Set 7 | batemans bay
# City not found. Skipping...
# Processing Record 33 of Set 7 | mul
# City not found. Skipping...
# Processing Record 34 of Set 7 | ariquemes
# City not found. Skipping...
# Processing Record 35 of Set 7 | bonavista
# City not found. Skipping...
# Processing Record 36 of Set 7 | axim
# City not found. Skipping...
# Processing Record 37 of Set 7 | poum
# City not found. Skipping...
# Processing Record 38 of Set 7 | nome
# City not found. Skipping...
# Processing Record 39 of Set 7 | komsomolskiy
# City not found. Skipping...
# Processing Record 40 of Set 7 | dunedin
# City not found. Skipping...
# Processing Record 41 of Set 7 | qandala
# City not found. Skipping...
# Processing Record 42 of Set 7 | salalah
# City not found. Skipping...
# Processing Record 43 of Set 7 | mwinilunga
# City not found. Skipping...
# Processing Record 44 of Set 7 | maloshuyka
# City not found. Skipping...
# Processing Record 45 of Set 7 | shangrao
# City not found. Skipping...
# Processing Record 46 of Set 7 | puerto escondido
# City not found. Skipping...
# Processing Record 47 of Set 7 | pathein
# City not found. Skipping...
# Processing Record 48 of Set 7 | jiazi
# City not found. Skipping...
# Processing Record 49 of Set 7 | lagoa
# City not found. Skipping...
# Processing Record 0 of Set 8 | mehamn
# City not found. Skipping...
# Processing Record 1 of Set 8 | jumla
# City not found. Skipping...
# Processing Record 2 of Set 8 | shahrud
# City not found. Skipping...
# Processing Record 3 of Set 8 | solano
# City not found. Skipping...
# Processing Record 4 of Set 8 | znamenskoye
# City not found. Skipping...
# Processing Record 5 of Set 8 | springbok
# City not found. Skipping...
# Processing Record 6 of Set 8 | gravdal
# City not found. Skipping...
# Processing Record 7 of Set 8 | mbour
# City not found. Skipping...
# Processing Record 8 of Set 8 | acapulco
# City not found. Skipping...
# Processing Record 9 of Set 8 | tanhacu
# City not found. Skipping...
# Processing Record 10 of Set 8 | dustlik
# City not found. Skipping...
# Processing Record 11 of Set 8 | high rock
# City not found. Skipping...
# Processing Record 12 of Set 8 | buenos aires
# City not found. Skipping...
# Processing Record 13 of Set 8 | stokmarknes
# City not found. Skipping...
# Processing Record 14 of Set 8 | aklavik
# City not found. Skipping...
# Processing Record 15 of Set 8 | bondo
# City not found. Skipping...
# Processing Record 16 of Set 8 | mundybash
# City not found. Skipping...
# Processing Record 17 of Set 8 | gisors
# City not found. Skipping...
# Processing Record 18 of Set 8 | sept-iles
# City not found. Skipping...
# Processing Record 19 of Set 8 | bethanien
# City not found. Skipping...
# Processing Record 20 of Set 8 | puerto ayacucho
# City not found. Skipping...
# Processing Record 21 of Set 8 | troitsko-pechorsk
# City not found. Skipping...
# Processing Record 22 of Set 8 | andros town
# City not found. Skipping...
# Processing Record 23 of Set 8 | blandiana
# City not found. Skipping...
# Processing Record 24 of Set 8 | binulasan
# City not found. Skipping...
# Processing Record 25 of Set 8 | bukama
# City not found. Skipping...
# Processing Record 26 of Set 8 | georgetown
# City not found. Skipping...
# Processing Record 27 of Set 8 | yar-sale
# City not found. Skipping...
# Processing Record 28 of Set 8 | kedrovyy
# City not found. Skipping...
# Processing Record 29 of Set 8 | mitsamiouli
# City not found. Skipping...
# Processing Record 30 of Set 8 | salinopolis
# City not found. Skipping...
# Processing Record 31 of Set 8 | talas
# City not found. Skipping...
# Processing Record 32 of Set 8 | vila
# City not found. Skipping...
# Processing Record 33 of Set 8 | iqaluit
# City not found. Skipping...
# Processing Record 34 of Set 8 | vaitape
# City not found. Skipping...
# Processing Record 35 of Set 8 | kungurtug
# City not found. Skipping...
# Processing Record 36 of Set 8 | atambua
# City not found. Skipping...
# Processing Record 37 of Set 8 | ratangarh
# City not found. Skipping...
# Processing Record 38 of Set 8 | diamantino
# City not found. Skipping...
# Processing Record 39 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 8 | puerto pinasco
# City not found. Skipping...
# Processing Record 41 of Set 8 | guicheng
# City not found. Skipping...
# Processing Record 42 of Set 8 | lasa
# City not found. Skipping...
# Processing Record 43 of Set 8 | le pradet
# City not found. Skipping...
# Processing Record 44 of Set 8 | xadani
# City not found. Skipping...
# Processing Record 45 of Set 8 | koumac
# City not found. Skipping...
# Processing Record 46 of Set 8 | grindavik
# City not found. Skipping...
# Processing Record 47 of Set 8 | anamur
# City not found. Skipping...
# Processing Record 48 of Set 8 | katherine
# City not found. Skipping...
# Processing Record 49 of Set 8 | anadyr
# City not found. Skipping...
# Processing Record 0 of Set 9 | zhigansk
# City not found. Skipping...
# Processing Record 1 of Set 9 | meulaboh
# City not found. Skipping...
# Processing Record 2 of Set 9 | shache
# City not found. Skipping...
# Processing Record 3 of Set 9 | pozo colorado
# City not found. Skipping...
# Processing Record 4 of Set 9 | sindor
# City not found. Skipping...
# Processing Record 5 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 9 | jasper
# City not found. Skipping...
# Processing Record 7 of Set 9 | kargat
# City not found. Skipping...
# Processing Record 8 of Set 9 | thoen
# City not found. Skipping...
# Processing Record 9 of Set 9 | tazovskiy
# City not found. Skipping...
# Processing Record 10 of Set 9 | ambulu
# City not found. Skipping...
# Processing Record 11 of Set 9 | lincoln
# City not found. Skipping...
# Processing Record 12 of Set 9 | brae
# City not found. Skipping...
# Processing Record 13 of Set 9 | okhotsk
# City not found. Skipping...
# Processing Record 14 of Set 9 | shchuchye
# City not found. Skipping...
# Processing Record 15 of Set 9 | vaovai
# City not found. Skipping...
# Processing Record 16 of Set 9 | ouahigouya
# City not found. Skipping...
# Processing Record 17 of Set 9 | stavern
# City not found. Skipping...
# Processing Record 18 of Set 9 | nalut
# City not found. Skipping...
# Processing Record 19 of Set 9 | tarnogskiy gorodok
# City not found. Skipping...
# Processing Record 20 of Set 9 | leningradskiy
# City not found. Skipping...
# Processing Record 21 of Set 9 | oksfjord
# City not found. Skipping...
# Processing Record 22 of Set 9 | port pirie
# City not found. Skipping...
# Processing Record 23 of Set 9 | semey
# City not found. Skipping...
# Processing Record 24 of Set 9 | bacuit
# City not found. Skipping...
# Processing Record 25 of Set 9 | selfoss
# City not found. Skipping...
# Processing Record 26 of Set 9 | mapiripan
# City not found. Skipping...
# Processing Record 27 of Set 9 | san jeronimo
# City not found. Skipping...
# Processing Record 28 of Set 9 | shelburne
# City not found. Skipping...
# Processing Record 29 of Set 9 | itapetinga
# City not found. Skipping...
# Processing Record 30 of Set 9 | barrow
# City not found. Skipping...
# Processing Record 31 of Set 9 | dalby
# City not found. Skipping...
# Processing Record 32 of Set 9 | hunza
# City not found. Skipping...
# Processing Record 33 of Set 9 | kahului
# City not found. Skipping...
# Processing Record 34 of Set 9 | ponta do sol
# City not found. Skipping...
# Processing Record 35 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 36 of Set 9 | narsaq
# City not found. Skipping...
# Processing Record 37 of Set 9 | guaruja
# City not found. Skipping...
# Processing Record 38 of Set 9 | touros
# City not found. Skipping...
# Processing Record 39 of Set 9 | ambilobe
# City not found. Skipping...
# Processing Record 40 of Set 9 | roebourne
# City not found. Skipping...
# Processing Record 41 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 42 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 9 | byron bay
# City not found. Skipping...
# Processing Record 44 of Set 9 | tayshet
# City not found. Skipping...
# Processing Record 45 of Set 9 | kincardine
# City not found. Skipping...
# Processing Record 46 of Set 9 | yinchuan
# City not found. Skipping...
# Processing Record 47 of Set 9 | inhambane
# City not found. Skipping...
# Processing Record 48 of Set 9 | honiara
# City not found. Skipping...
# Processing Record 49 of Set 9 | nizwa
# City not found. Skipping...
# Processing Record 0 of Set 10 | sola
# City not found. Skipping...
# Processing Record 1 of Set 10 | sandakan
# City not found. Skipping...
# Processing Record 2 of Set 10 | ploemeur
# City not found. Skipping...
# Processing Record 3 of Set 10 | katsina
# City not found. Skipping...
# Processing Record 4 of Set 10 | lashio
# City not found. Skipping...
# Processing Record 5 of Set 10 | maltahohe
# City not found. Skipping...
# Processing Record 6 of Set 10 | pervomaysk
# City not found. Skipping...
# Processing Record 7 of Set 10 | tabou
# City not found. Skipping...
# Processing Record 8 of Set 10 | khalkhal
# City not found. Skipping...
# Processing Record 9 of Set 10 | avera
# City not found. Skipping...
# Processing Record 10 of Set 10 | mae sai
# City not found. Skipping...
# Processing Record 11 of Set 10 | cabo san lucas
# City not found. Skipping...
# Processing Record 12 of Set 10 | klaksvik
# City not found. Skipping...
# Processing Record 13 of Set 10 | zeya
# City not found. Skipping...
# Processing Record 14 of Set 10 | la asuncion
# City not found. Skipping...
# Processing Record 15 of Set 10 | pindiga
# City not found. Skipping...
# Processing Record 16 of Set 10 | dawlatabad
# City not found. Skipping...
# Processing Record 17 of Set 10 | manta
# City not found. Skipping...
# Processing Record 18 of Set 10 | berdigestyakh
# City not found. Skipping...
# Processing Record 19 of Set 10 | pevek
# City not found. Skipping...
# Processing Record 20 of Set 10 | beloha
# City not found. Skipping...
# Processing Record 21 of Set 10 | tchibanga
# City not found. Skipping...
# Processing Record 22 of Set 10 | koutiala
# City not found. Skipping...
# Processing Record 23 of Set 10 | andenes
# City not found. Skipping...
# Processing Record 24 of Set 10 | tura
# City not found. Skipping...
# Processing Record 25 of Set 10 | homer
# City not found. Skipping...
# Processing Record 26 of Set 10 | labuhan
# City not found. Skipping...
# Processing Record 27 of Set 10 | dekar
# City not found. Skipping...
# Processing Record 28 of Set 10 | moroto
# City not found. Skipping...
# Processing Record 29 of Set 10 | lavrentiya
# City not found. Skipping...
# Processing Record 30 of Set 10 | maghama
# City not found. Skipping...
# Processing Record 31 of Set 10 | oxelosund
# City not found. Skipping...
# Processing Record 32 of Set 10 | ordu
# City not found. Skipping...
# Processing Record 33 of Set 10 | sitka
# City not found. Skipping...
# Processing Record 34 of Set 10 | mayya
# City not found. Skipping...
# Processing Record 35 of Set 10 | kijang
# City not found. Skipping...
# Processing Record 36 of Set 10 | orotukan
# City not found. Skipping...
# Processing Record 37 of Set 10 | lar
# City not found. Skipping...
# Processing Record 38 of Set 10 | ilinskiy
# City not found. Skipping...
# Processing Record 39 of Set 10 | bilma
# City not found. Skipping...
# Processing Record 40 of Set 10 | saint-augustin
# City not found. Skipping...
# Processing Record 41 of Set 10 | hobyo
# City not found. Skipping...
# Processing Record 42 of Set 10 | benguela
# City not found. Skipping...
# Processing Record 43 of Set 10 | kinanah
# City not found. Skipping...
# Processing Record 44 of Set 10 | yago
# City not found. Skipping...
# Processing Record 45 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 46 of Set 10 | vakhrushev
# City not found. Skipping...
# Processing Record 47 of Set 10 | kholmy
# City not found. Skipping...
# Processing Record 48 of Set 10 | owando
# City not found. Skipping...
# Processing Record 49 of Set 10 | katsuura
# City not found. Skipping...
# Processing Record 0 of Set 11 | sobolevo
# City not found. Skipping...
# Processing Record 1 of Set 11 | roald
# City not found. Skipping...
# Processing Record 2 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 3 of Set 11 | mombasa
# City not found. Skipping...
# Processing Record 4 of Set 11 | mandalgovi
# City not found. Skipping...
# Processing Record 5 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 6 of Set 11 | christchurch
# City not found. Skipping...
# Processing Record 7 of Set 11 | pochutla
# City not found. Skipping...
# Processing Record 8 of Set 11 | kushmurun
# City not found. Skipping...
# Processing Record 9 of Set 11 | sambava
# City not found. Skipping...
# Processing Record 10 of Set 11 | kontagora
# City not found. Skipping...
# Processing Record 11 of Set 11 | talah
# City not found. Skipping...
# Processing Record 12 of Set 11 | vangaindrano
# City not found. Skipping...
# Processing Record 13 of Set 11 | freeport
# City not found. Skipping...
# Processing Record 14 of Set 11 | iberia
# City not found. Skipping...
# Processing Record 15 of Set 11 | poshekhonye
# City not found. Skipping...
# Processing Record 16 of Set 11 | leca da palmeira
# City not found. Skipping...
# Processing Record 17 of Set 11 | merritt island
# City not found. Skipping...
# Processing Record 18 of Set 11 | kiama
# City not found. Skipping...
# Processing Record 19 of Set 11 | lima
# City not found. Skipping...
# Processing Record 20 of Set 11 | starodub
# City not found. Skipping...
# Processing Record 21 of Set 11 | adrar
# City not found. Skipping...
# Processing Record 22 of Set 11 | juruti
# City not found. Skipping...
# Processing Record 23 of Set 11 | anshun
# City not found. Skipping...
# Processing Record 24 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 25 of Set 11 | dovbysh
# City not found. Skipping...
# Processing Record 26 of Set 11 | ahipara
# City not found. Skipping...
# Processing Record 27 of Set 11 | evensk
# City not found. Skipping...
# Processing Record 28 of Set 11 | talnakh
# City not found. Skipping...
# Processing Record 29 of Set 11 | kawana waters
# City not found. Skipping...
# Processing Record 30 of Set 11 | baykit
# City not found. Skipping...
# Processing Record 31 of Set 11 | sinnamary
# City not found. Skipping...
# Processing Record 32 of Set 11 | gwadar
# City not found. Skipping...
# Processing Record 33 of Set 11 | pangnirtung
# City not found. Skipping...
# Processing Record 34 of Set 11 | vardo
# City not found. Skipping...
# Processing Record 35 of Set 11 | kalmunai
# City not found. Skipping...
# Processing Record 36 of Set 11 | presidencia roque saenz pena
# City not found. Skipping...
# Processing Record 37 of Set 11 | coos bay
# City not found. Skipping...
# Processing Record 38 of Set 11 | redmond
# City not found. Skipping...
# Processing Record 39 of Set 11 | kizner
# City not found. Skipping...
# Processing Record 40 of Set 11 | enshi
# City not found. Skipping...
# Processing Record 41 of Set 11 | melfi
# City not found. Skipping...
# Processing Record 42 of Set 11 | shanghai
# City not found. Skipping...
# Processing Record 43 of Set 11 | kanbe
# City not found. Skipping...
# Processing Record 44 of Set 11 | fairbanks
# City not found. Skipping...
# Processing Record 45 of Set 11 | tucuma
# City not found. Skipping...
# Processing Record 46 of Set 11 | alugan
# City not found. Skipping...
# Processing Record 47 of Set 11 | yantal
# City not found. Skipping...
# Processing Record 48 of Set 11 | bereda
# City not found. Skipping...
# Processing Record 49 of Set 11 | ashland
# City not found. Skipping...
# Processing Record 0 of Set 12 | enid
# City not found. Skipping...
# Processing Record 1 of Set 12 | broken hill
# City not found. Skipping...
# Processing Record 2 of Set 12 | palafrugell
# City not found. Skipping...
# Processing Record 3 of Set 12 | tigil
# City not found. Skipping...
# Processing Record 4 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 5 of Set 12 | los lunas
# City not found. Skipping...
# Processing Record 6 of Set 12 | springdale
# City not found. Skipping...
# Processing Record 7 of Set 12 | saint-louis
# City not found. Skipping...
# Processing Record 8 of Set 12 | riachao das neves
# City not found. Skipping...
# Processing Record 9 of Set 12 | bambous virieux
# City not found. Skipping...
# Processing Record 10 of Set 12 | gornyy
# City not found. Skipping...
# Processing Record 11 of Set 12 | mangochi
# City not found. Skipping...
# Processing Record 12 of Set 12 | susanville
# City not found. Skipping...
# Processing Record 13 of Set 12 | nusaybin
# City not found. Skipping...
# Processing Record 14 of Set 12 | suntar
# City not found. Skipping...
# Processing Record 15 of Set 12 | alta floresta
# City not found. Skipping...
# Processing Record 16 of Set 12 | nantucket
# City not found. Skipping...
# Processing Record 17 of Set 12 | butterworth
# City not found. Skipping...
# Processing Record 18 of Set 12 | nyborg
# City not found. Skipping...
# Processing Record 19 of Set 12 | takhtamygda
# City not found. Skipping...
# Processing Record 20 of Set 12 | maarianhamina
# City not found. Skipping...
# Processing Record 21 of Set 12 | dhemaji
# City not found. Skipping...
# Processing Record 22 of Set 12 | plettenberg bay
# City not found. Skipping...
# Processing Record 23 of Set 12 | srednekolymsk
# City not found. Skipping...
# Processing Record 24 of Set 12 | flin flon
# City not found. Skipping...
# Processing Record 25 of Set 12 | valparaiso
# City not found. Skipping...
# Processing Record 26 of Set 12 | akhmim
# City not found. Skipping...
# Processing Record 27 of Set 12 | moron
# City not found. Skipping...
# Processing Record 28 of Set 12 | constitucion
# City not found. Skipping...
# Processing Record 29 of Set 12 | bud
# City not found. Skipping...
# Processing Record 30 of Set 12 | areosa
# City not found. Skipping...
# Processing Record 31 of Set 12 | khasan
# City not found. Skipping...
# Processing Record 32 of Set 12 | mocuba
# City not found. Skipping...
# Processing Record 33 of Set 12 | fort nelson
# City not found. Skipping...
# Processing Record 34 of Set 12 | ceres
# City not found. Skipping...
# Processing Record 35 of Set 12 | magadi
# City not found. Skipping...
# Processing Record 36 of Set 12 | mooi river
# City not found. Skipping...
# Processing Record 37 of Set 12 | harnai
# City not found. Skipping...
# Processing Record 38 of Set 12 | ginir
# City not found. Skipping...
# Processing Record 39 of Set 12 | port-gentil
# City not found. Skipping...
# Processing Record 40 of Set 12 | stryn
# City not found. Skipping...
# Processing Record 41 of Set 12 | general roca
# City not found. Skipping...
# Processing Record 42 of Set 12 | mana
# City not found. Skipping...
# Processing Record 43 of Set 12 | mattru
# City not found. Skipping...
# Processing Record 44 of Set 12 | snezhnogorsk
# City not found. Skipping...
# Processing Record 45 of Set 12 | tres arroyos
# City not found. Skipping...
# Processing Record 46 of Set 12 | sirsa
# City not found. Skipping...
# Processing Record 47 of Set 12 | tokoroa
# City not found. Skipping...
# Processing Record 48 of Set 12 | sao paulo de olivenca
# City not found. Skipping...
# Processing Record 49 of Set 12 | kota
# City not found. Skipping...
# Processing Record 0 of Set 13 | bilibino
# City not found. Skipping...
# Processing Record 1 of Set 13 | kabanjahe
# City not found. Skipping...
# Processing Record 2 of Set 13 | dubti
# City not found. Skipping...
# Processing Record 3 of Set 13 | kwinana
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

city_data_df

# Show Record Count
city_data_df.count()

# %%
# Display sample data
city_data_df.head()

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature

# Set the size and style of the markers
markersize=15
markerstyle='o'

# Set the opacity of the markers
alpha=0.6

# Plot the scatter plot with the specified markers and alpha value
city_data_df.plot.scatter(x='Lat', y='Max Temp', s=markersize, marker=markerstyle, alpha=alpha)

# Add the x-axis label
plt.xlabel('Latitude')

# Add the y-axis label
plt.ylabel('Max Temperature (C)')

# Set the plot title
plt.title('City Latitude vs Temperature')

# Show the plot
plt.show()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/sr/pdhryvkj29v9v3m0rlsrr8dm0000gn/T/ipykernel_8159/917059615.py in <module>
#       9
#      10 # Plot the scatter plot with the specified markers and alpha value
# ---> 11 city_data_df.plot.scatter(x='Lat', y='Max Temp', s=markersize, marker=markerstyle, alpha=alpha)
#      12
#      13 # Add the x-axis label
#
# NameError: name 'city_data_df' is not defined

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot.scatter(x='Lat', y='Humidity', s=markersize, marker=markerstyle, alpha=alpha)

# Incorporate the other graph properties
# Set the size and style of the markers
markersize=15
markerstyle='o'

# Set the opacity of the markers
alpha=0.6

# Add the x-axis label
plt.xlabel('Latitude')

# Add the y-axis label
plt.ylabel('Humididty %')

# Set the plot title
plt.title('City Latitude vs Humidity')


# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot.scatter(x='Lat', y="Cloudiness", s=markersize, marker=markerstyle, alpha=alpha)

# Incorporate the other graph properties

# Set the size and style of the markers
markersize=15
markerstyle='o'

# Set the opacity of the markers
alpha=0.6

# Add the x-axis label
plt.xlabel('Latitude')

# Add the y-axis label
plt.ylabel('Cloudiness')

# Set the plot title
plt.title('City Latitude vs Cloudiness')


# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %%
#### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot.scatter(x='Lat', y='Wind Speed', s=markersize, marker=markerstyle, alpha=alpha)

# Incorporate the other graph properties

# Set the size and style of the markers
markersize=15
markerstyle='o'

# Set the opacity of the markers
alpha=0.6

# Add the x-axis label
plt.xlabel('Latitude')

# Add the y-axis label
plt.ylabel('Wind Speed')

# Set the plot title
plt.title('City Latitude vs Wind Speed')

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots


def plot_linear_regression(x, y, y_pred, title, xlabel, ylabel):
    plt.scatter(x, y, color='blue')
    plt.plot(x, y_pred, color='red')
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)


southern_hemi_df = city_data_df[city_data_df["Lat"] <= 0]

# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
x = northern_hemi_df["Lat"]
y = northern_hemi_df["Max Temp"]

#create basic scatterplot
plt.plot(x, y, 'o')

#obtain m (slope) and b(intercept) of linear regression line
m, b = np.polyfit(x, y, 1)

#add linear regression line to scatterplot 
plt.plot(x, m*x+b)

# %%
#Correlation Coefecient
correlation = northern_hemi_df["Lat"].corr(northern_hemi_df["Max Temp"])

print("The correlation coefficient between lattitude and temperature  is:", correlation)

# %%
# Linear regression on Southern Hemisphere

x = southern_hemi_df["Lat"]
y = southern_hemi_df["Max Temp"]

#create basic scatterplot
plt.plot(x, y, 'o')

#obtain m (slope) and b(intercept) of linear regression line
m, b = np.polyfit(x, y, 1)

#add linear regression line to scatterplot 
plt.plot(x, m*x+b)

# %%
#Correlation Coefecient
correlation = southern_hemi_df["Lat"].corr(southern_hemi_df["Max Temp"])

print("The correlation coefficient between lattitude and temperature  is:", correlation)

# %% [markdown]
# **Discussion about the linear relationship:**
#
# #### The correlation coefficient measures the strength and direction of a linear relationship between two variables. A coefficient of 1 means a perfect positive relationship, -1 a perfect negative relationship and 0 means no relationship at all.
#
# #### In the Northern Hemisphere, the correlation coefficient between latitude and temperature is -0.87, indicating a strong negative relationship. This suggests that as you move towards the poles (increasing latitude), the temperature decreases.
#
# #### In the Southern Hemisphere, the correlation coefficient between latitude and temperature is 0.42, indicating a moderate positive relationship. This suggests that as you move towards the equator (decreasing latitude), the temperature increases.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x = northern_hemi_df["Lat"]
y = northern_hemi_df["Humidity"]

#create basic scatterplot
plt.plot(x, y, 'o')

#obtain m (slope) and b(intercept) of linear regression line
m, b = np.polyfit(x, y, 1)

#add linear regression line to scatterplot 
plt.plot(x, m*x+b)

# %%
#Correlation Coefecient
correlation = northern_hemi_df["Lat"].corr(northern_hemi_df["Humidity"])

print("The correlation coefficient between lattitude and humidity  is:", correlation)

# %%
# Southern Hemisphere
x = southern_hemi_df["Lat"]
y = southern_hemi_df["Humidity"]

#create basic scatterplot
plt.plot(x, y, 'o')

#obtain m (slope) and b(intercept) of linear regression line
m, b = np.polyfit(x, y, 1)

#add linear regression line to scatterplot 
plt.plot(x, m*x+b)

# %%
#Correlation Coefecient
correlation = southern_hemi_df["Lat"].corr(southern_hemi_df["Humidity"])

print("The correlation coefficient between lattitude and humididty  is:", correlation)

# %% [markdown]
# **Discussion about the linear relationship:**
#
#
# #### The correlation coefficient measures the linear relationship between two variables, with a value of 1 indicating a perfect positive correlation, -1 indicating a perfect negative correlation, and 0 indicating no correlation.
#
# #### In the case of the Northern hemisphere, the correlation coefficient between latitude and humidity is 0.50, which suggests a moderate positive correlation.
#
# #### In the case of the Southern hemisphere, the correlation coefficient between latitude and humidity is 0.34, which suggests a weaker positive correlation. These values indicate that latitude and humidity have a positive relationship in both hemispheres, but the relationship is stronger in the Northern hemisphere.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
import seaborn as sns

sns.regplot(x=northern_hemi_df['Lat'], y=northern_hemi_df['Cloudiness'], data=northern_hemi_df)

plt.show

# %%
#Correlation Coefecient
correlation = northern_hemi_df["Lat"].corr(northern_hemi_df["Cloudiness"])

print("The correlation coefficient between cloudiness and lattitude linear regression  is:", correlation)

# %%
#Southern Hemisphere
sns.regplot(x=southern_hemi_df['Lat'], y=southern_hemi_df['Cloudiness'], data=southern_hemi_df)

plt.show

# %%
#Correlation Coefecient
correlation = northern_hemi_df["Lat"].corr(northern_hemi_df["Cloudiness"])

print("The correlation coefficient between lattitude and cloudiness linear regression is:", correlation)

# %% [markdown]
# **Discussion about the linear relationship:**
#
# #### The correlation coefficient between two variables is a measure of the strength and direction of the relationship between them. A correlation coefficient of 0.2645902036297792 indicates a weak positive correlation between cloudiness and lattitude. This means that as lattitude increases, cloudiness tends to increase as well, but the relationship is not strong.
#
# #### The fact that the correlation coefficient is the same when calculating the relationship between lattitude and cloudiness as compared to cloudiness and lattitude, just shows that the correlation is symmetrical and the relationship between the two variables is the same in either direction.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
sns.regplot(x=northern_hemi_df['Lat'], y=northern_hemi_df['Wind Speed'], data=northern_hemi_df)

plt.show

# %%
#Correlation Coefecient
correlation = northern_hemi_df["Lat"].corr(northern_hemi_df["Wind Speed"])

print("The correlation coefficient between windspeed and lattitude linear regression  is:", correlation)

# %%
# Southern Hemisphere

sns.regplot(x=southern_hemi_df['Lat'], y=southern_hemi_df['Wind Speed'], data=southern_hemi_df)

plt.show

# %%
#Correlation Coefecient
correlation = southern_hemi_df["Lat"].corr(southern_hemi_df["Wind Speed"])

print("The correlation coefficient between latttitude and windspeed linear regression  is:", correlation)

# %% [markdown]
# **Discussion about the linear relationship:**
#
#
# #### The correlation coefficients between wind speed and latitude in both hemispheres suggest a weak relationship. In the southern hemisphere, there is a negative correlation (-0.42) meaning as latitude increases, wind speed decreases. In the northern hemisphere, the correlation coefficient is close to 0 (0.0028), indicating no significant relationship between wind speed and latitude.
#
# #### Linear regression can be used to model the relationship between wind speed and latitude and make predictions. However, a weak correlation between the two variables may result in a poor model fit and unreliable predictions. Further analysis and consideration of other factors affecting wind speed is necessary to build a robust model.
